# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Tạo dữ liệu giả lập (21 thời điểm, 100 chiều)
np.random.seed(42)
data = np.random.rand(21, 10)

# Tính ma trận tương quan giữa các features
adj_matrix = np.corrcoef(data.T)

# Vẽ heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(adj_matrix, cmap='coolwarm', annot=False)
plt.title("Feature Adjacency Matrix (100x100)")
plt.show()
